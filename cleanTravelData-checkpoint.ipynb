# %%
import pandas as pd
travel_csv = "Data/Trips_by_Distance.txt"
travel_df = pd.read_csv(travel_csv)

# %%
travel_df.head()
# Out:
#     Level        Date  State FIPS State Postal Code  County FIPS  \
# 0  County  2019/01/21        48.0                TX      48347.0
# 1  County  2019/01/21        48.0                TX      48349.0
# 2  County  2019/01/21        48.0                TX      48351.0
# 3  County  2019/01/21        48.0                TX      48353.0
# 4  County  2019/01/21        48.0                TX      48355.0
#
#           County Name  Population Staying at Home  \
# 0  Nacogdoches County                     12059.0
# 1      Navarro County                      7986.0
# 2       Newton County                      1857.0
# 3        Nolan County                      3120.0
# 4       Nueces County                     60909.0
#
#    Population Not Staying at Home  Number of Trips  Number of Trips <1  \
# 0                         53451.0         215056.0             51075.0
# 1                         41428.0         166879.0             37369.0
# ...

# %%
travel_df["DateNew"] = travel_df["Date"]
travel_df.head()
# Out:
#     Level        Date  State FIPS State Postal Code  County FIPS  \
# 0  County  2019/01/21        48.0                TX      48347.0
# 1  County  2019/01/21        48.0                TX      48349.0
# 2  County  2019/01/21        48.0                TX      48351.0
# 3  County  2019/01/21        48.0                TX      48353.0
# 4  County  2019/01/21        48.0                TX      48355.0
#
#           County Name  Population Staying at Home  \
# 0  Nacogdoches County                     12059.0
# 1      Navarro County                      7986.0
# 2       Newton County                      1857.0
# 3        Nolan County                      3120.0
# 4       Nueces County                     60909.0
#
#    Population Not Staying at Home  Number of Trips  Number of Trips <1  \
# 0                         53451.0         215056.0             51075.0
# 1                         41428.0         166879.0             37369.0
# ...

# %%
travel_df.sort_values(by=["Date"])
travel_df["Date"].nunique()
travel_df.dtypes
# Out:
# Level                              object
# Date                               object
# State FIPS                        float64
# State Postal Code                  object
# County FIPS                       float64
# County Name                        object
# Population Staying at Home        float64
# Population Not Staying at Home    float64
# Number of Trips                   float64
# Number of Trips <1                float64
# Number of Trips 1-3               float64
# Number of Trips 3-5               float64
# Number of Trips 5-10              float64
# Number of Trips 10-25             float64
# Number of Trips 25-50             float64
# Number of Trips 50-100            float64
# Number of Trips 100-250           float64
# Number of Trips 250-500           float64
# Number of Trips >=500             float64
# DateNew                            object
# dtype: object

# %%
travel_df.to_datetime(travel_df.Series(['05/23/2005']), format="%m/%d/%Y")
# Out:
# Level                              object
# Date                               object
# State FIPS                        float64
# State Postal Code                  object
# County FIPS                       float64
# County Name                        object
# Population Staying at Home        float64
# Population Not Staying at Home    float64
# Number of Trips                   float64
# Number of Trips <1                float64
# Number of Trips 1-3               float64
# Number of Trips 3-5               float64
# Number of Trips 5-10              float64
# Number of Trips 10-25             float64
# Number of Trips 25-50             float64
# Number of Trips 50-100            float64
# Number of Trips 100-250           float64
# Number of Trips 250-500           float64
# Number of Trips >=500             float64
# dtype: object

# %%
travel_df["DateNew"]: pd.to_datetime(pd.Series(["2019/01/21"]), format="%y/%m/%d")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     431             try:
# --> 432                 values, tz = conversion.datetime_to_datetime64(arg)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-8923cedc20a2> in <module>
# ----> 1 travel_df["DateNew"]: pd.to_datetime(pd.Series(["2019/01/21"]), format="%y/%m/%d")
#
# ...
